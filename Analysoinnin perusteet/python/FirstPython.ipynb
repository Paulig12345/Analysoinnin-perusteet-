# %%
## comment
print ("Hello this is my first pyhton code")
# Out:
# Hello this is my first pyhton code

# %% [markdown]
# Koodiesimerkkejä

# %%
#kommentti
'''Pitkä  kommentti
jatkuu usealla rivillä'''
print("hello")


x=3; y=6

z = 1 + 2 + 4 + 6 \
+ 7 + 7 

print(z)
# Out:
# hello
# 27

# %%
n = 3.7
print(n)
# Out:
# 3.7

# %%
print(True and True)
print(True & True)
print(True or False)
print(True | False)
# Out:
# True
# True
# True
# True

# %%
n ="Merkkijono"
type(n)
# Out:
# str

# %%
print( n + 7)
# Out:
# 10.7

# %%
mystring = "Merkkijono"

print(mystring[0])
print(mystring[0:3])
# Out:
# M
# Mer

# %%
text = "Puuhöylä"
text2 = " jatkuu"
num1 = 3

print(text + text2, 3)
# Out:
# Puuhöylä jatkuu 3

# %%
#Simppelit If lausekkeet
#input to get input from the user

grade = int (input("What is your grade for IOT?"))
if grade >= 1:
     print("You have successfully passed the course.")
else:
     print("Second printing")
# Out:
# You have successfully passed the course.

# %%
grades =[4,5,2,4]
for grade in grades:
    print(grade)
# Out:
# 4
# 5
# 2
# 4
