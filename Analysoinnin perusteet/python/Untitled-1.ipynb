# %%
print("Printer App")
creator = "Pauli"
print("This App made by" ,creator)
#print(creator)
#gitti testi
number1 = 6
number2 = 3
#print(number1)
print(number1 + number2)

multiplication=(int)
multiplication = number1 * number2
print(number1 * number2)
# Out:
# Printer App
# This App made by Pauli
# 9
# 18

# %%
print("This App is made by", creator)
# Out:
# This App is made by Pauli

# %%
number1 = 6
number2 = 3
#print(number1)
print(number1 + number2)
# Out:
# 9

# %%
multiplication=(int)
multiplication = number1 * number2
print(number1 * number2)
# Out:
# 18

# %%
multiplication1=(int)
multiplication1 = number1 - number2
print(multiplication1)
# Out:
# 3
