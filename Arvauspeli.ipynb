# %%
huonekalut = ["pöytä", "tuoli", "hylly", "sohva"]

print(huonekalut)

print(huonekalut[0], huonekalut[1])

for esine in huonekalut:
    if esine.lower() == "sohva":
        print(esine)
# Out:
# 1b: number1 is greater than number2
# 1c: number1 is greater or equal to number2
# 1d: number1 and number2 are NOT equal

# %%
import random

heitetytNopat = [0, 0, 0, 0, 0]

for i in range(5):
    heitetytNopat[i] = random.randint(1, 6)

print(heitetytNopat)

summa = sum(heitetytNopat)
print(summa)

print(max(heitetytNopat))
# Out:
# 3b: name1 and name2 are NOT equal
