# %%
import pandas as pd

data = pd.read_csv("games.csv")

# %%
nominal_columns = data.select_dtypes(include=['object', 'category']).columns

print
for col in nominal_columns:
    print(col)
# Out:
# Title
# Release Date
# Team
# Times Listed
# Number of Reviews
# Genres
# Summary
# Reviews
# Plays
# Playing
# Backlogs
# Wishlist

# %%
binary_columns = [col for col in data.columns if data[col].nunique() == 2]

print("Binääriset attribuutit :")
for col in binary_columns:
    print(f"{col}: {data[col].unique()}")
# Out:
# Binääriset attribuutit :
